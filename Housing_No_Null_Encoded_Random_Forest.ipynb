# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housing_data_train = pd.read_csv('./housing_data/train.csv')

# %%
housing_data_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
housing_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
housing_data_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print(housing_data_train.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
Y_train = housing_data_train.SalePrice
print(Y_train.shape)
# Out:
# (1460,)

# %%
X_train = housing_data_train.drop('SalePrice', axis=1)
print(X_train.shape)
# Out:
# (1460, 80)

# %%
X_train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
missing_val_count_by_col = X_train.isnull().sum()
#print(missing_val_count_by_col[missing_val_count_by_col>0])
#print(missing_val_count_by_col.count())

#missing_val_count_by_col_test = X_test.isnull().sum()
#print(missing_val_count_by_col_test[missing_val_count_by_col_test>0])
#print(missing_val_count_by_col_test.count())
#print(X.LotFrontage.isnull().any())

na_col = [col for col in X_train.columns if(X_train[col].isnull().any())]
print(na_col)
print(np.mean(X_train.LotFrontage))
#X_train.LotFrontage.plot(kind='hist')
X_train.LotFrontage.plot.kde()
plt.show()
#X_train.LotFrontage.fillna(value=np.mean(X_train.LotFrontage))
# Out:
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']
# 70.04995836802665

# %%
# Drop all null columns
X_train_no_null = X_train.drop(na_col, axis=1)
print(X_train_no_null.shape)
X_train_no_null.head()
# Out:
# (1460, 61)
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0    Inside       Gtl      ...               61             0         0
# 1       FR2       Gtl      ...                0             0         0
# 2    Inside       Gtl      ...               42             0         0
# 3    Corner       Gtl      ...               35           272         0
# 4       FR2       Gtl      ...               84             0         0
#
#   ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition
# ...

# %%
# Exclude object type labels
#X_train_no_null_num = X_train_no_null.select_dtypes(exclude='object')
#print(X_train_no_null_num.shape)

# One-hot encode labels that are object
"""object_cols = X_train_no_null.select_dtypes(include='object').columns
tmp = X_train_no_null[object_cols]
tmp = pd.get_dummies(tmp)
tmp.head()"""
X_train_no_null_encoded = pd.get_dummies(X_train_no_null)
X_train_no_null_encoded.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF          ...            SaleType_ConLw  \
# 0         706           0        150          ...                         0
# 1         978           0        284          ...                         0
# 2         486           0        434          ...                         0
# 3         216           0        540          ...                         0
# 4         655           0        490          ...                         0
#
# ...

# %%
import sklearn
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor(max_leaf_nodes=50, random_state=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X_train_no_null_encoded, Y_train, test_size=0.33, random_state=1)
print(x_train.shape)
print(x_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (978, 216)
# (482, 216)
# (978,)
# (482,)

# %%
# Fit the training data
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=50, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
# Predict the data
y_pred = dt.predict(x_val)

# %%
print("Making predictions for the following 5 houses")
#print(x_val.head())
print("The predictions are")
print(dt.predict(x_val.head()))
#print(x_val.Id.head())
print( (lambda p: [housing_data_train[housing_data_train.Id==i].SalePrice for i in p.Id])(x_val.head()))
# Out:
# Making predictions for the following 5 houses
# The predictions are
# [217353.375      137726.96428571 111465.78947368  72425.
#  162275.12280702]
# [258    231500
# Name: SalePrice, dtype: int64, 267    179500
# Name: SalePrice, dtype: int64, 288    122000
# Name: SalePrice, dtype: int64, 649    84500
# Name: SalePrice, dtype: int64, 1233    142000
# Name: SalePrice, dtype: int64]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
print(y_val.shape)
print(y_pred.shape)
# Out:
# (482,)
# (482,)

# %%
rms = sqrt(mean_squared_error(y_val, y_pred))
print(rms)
# Out:
# 44227.47277682546

# %%
def get_rms(max_range, train_x, train_y, val_x, val_y):
    rms=[]
    for leaf_nodes in range(50,5000,50):
        model = DecisionTreeRegressor(max_leaf_nodes= leaf_nodes, random_state=1)
        model.fit(train_x, train_y)
        pred_y = model.predict(val_x)
        rms.append(sqrt(mean_squared_error(val_y, pred_y)))
    print("Minimum rms value is %f at max leaves %d" %(min(rms), 50*rms.index(min(rms))))
get_rms(1000, x_train, y_train, x_val, y_val)
# Out:
# Minimum rms value is 42849.377584 at max leaves 100

# %%
# Random Forest Implementation
import sklearn
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(random_state=1)

# %%
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
y_pred_rf = rf_model.predict(x_val)

# %%
rms_rf = sqrt(mean_squared_error(y_val, y_pred_rf))
print(rms_rf)
# Out:
# 27912.90270629367

# %%
# Load the test csv
test_housing_data = pd.read_csv('./housing_data/test.csv')

# %%
rf_model_full = RandomForestRegressor()

# %%
rf_model_full.fit(X_train_no_null_encoded, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
test_X = test_housing_data
test_X.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# Pre process the data same as train
# Drop all null columns same as in train
# Exclude columns that are not numeric
test_X_no_null_encoded = pd.get_dummies(test_X.drop(na_col, axis=1))
print(test_X_no_null_encoded.shape)
test_X_no_null_num.isnull().sum()
new_test_X = test_X_no_null_encoded.dropna(axis=0)
print(new_test_X.shape)

# see the columns that are in the training set but not in the test set
print(set(X_train_no_null_encoded.columns) - set(new_test_X))
# Out:
# (1459, 202)
# (1456, 202)
# {'Condition2_RRAe', 'Condition2_RRNn', 'RoofMatl_Membran', 'Exterior1st_ImStucc', 'Condition2_RRAn', 'Exterior1st_Stone', 'RoofMatl_Metal', 'HouseStyle_2.5Fin', 'RoofMatl_Roll', 'Heating_Floor', 'RoofMatl_ClyTile', 'Heating_OthW', 'Exterior2nd_Other', 'Utilities_NoSeWa'}

# %%
# will not be able to predict the test data as the no of columns are mismatch
## see the above the print statement
test_pred_Y = rf_model_full.predict(new_test_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-5bf5bd8687c4> in <module>()
# ----> 1 test_pred_Y = rf_model_full.predict(new_test_X)
#
# /usr/lib/python3.7/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     679         check_is_fitted(self, 'estimators_')
#     680         # Check data
# --> 681         X = self._validate_X_predict(X)
#     682
#     683         # Assign chunk of trees to jobs
#
# /usr/lib/python3.7/site-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     355                                  "call `fit` before exploiting the model.")
#     356
# --> 357         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     358
#     359     @property
#
# /usr/lib/python3.7/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
# ...

# %%
output = pd.DataFrame({'Id':new_test_X.Id, 'SalePrice' : test_pred_Y})

# %%
output.to_csv('submission_no_null_encoded_random_forest.csv', index=False)

# %%
p = pd.read_csv('submission_no_null_encoded_random_forest.csv')
p.head()
# Out:
#      Id  SalePrice
# 0  1461   129500.0
# 1  1462   173490.0
# 2  1463   182550.0
# 3  1464   184950.0
# 4  1465   199556.5
